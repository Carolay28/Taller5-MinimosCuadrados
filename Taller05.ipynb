# %% [markdown]
# ## TALLER 05
#
# Nombre: Carolay Pillajo
#
# Curso: 15/12/2025
#
# A)  Interpole los puntos:
# $p1 = (5.4, 3.2)$; $p2 = (9.5, 0.7)$; $p3 = (12.3, -3.6)$

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados

# UTILICE:
ajustar_min_cuadrados([5.4, 9.5, 12.3], [3.2, 0.7, -3.6], [der_parcial_1, der_parcial_0])
# Out:
# [12-15 20:20:38][INFO] Se ajustarán 2 parámetros.
# array([-0.95779131,  8.78397454])

# %%
import numpy as np
import matplotlib.pyplot as plt

xs = np.array([5.4, 9.5, 12.3])
ys = np.array([3.2, 0.7, -3.6])

m = -0.95779131
b = 8.78397454

x_recta = np.linspace(5, 13, 200)
y_recta = m * x_recta + b

plt.figure()
plt.scatter(xs, ys, color='red', s=60, label="Puntos dados")
plt.plot(x_recta, y_recta, label="Recta de mínimos cuadrados")

plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# B) Interpole el siguiente conjunto de datos:
#
# Conjunto de datos 1
#
# $xs = [ 3.38,
# 0.35,
# 2.07,
# -0.45,
# -0.55,
# -1.06,
# -2.77,
# 3.08,
# -3.98,
# -5.
# -3.18,
# -1.96,
# 2.37,
# -1.66,
# 4.09]$
#
# $ys = [-0.04,
# 1.28,
# 0.65,
# 2.18,
# 1.70,
# 1.96,
# 3.36,
# 0.18,
# 3.35,
# 4.16,
# 2.95,
# 2.34,
# 0.38,
# 1.75,
# -1.06]$

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados

# UTILICE:
ajustar_min_cuadrados([3.38, 0.35, 2.07, -0.45, -0.55, -1.06, -2.77, 3.08, -3.98, -5, -3.18, -1.96, 2.37, -1.66,
4.09], [-0.04, 1.28, 0.65, 2.18, 1.70, 1.96, 3.36, 0.18, 3.35, 4.16, 2.95, 2.34, 0.38, 1.75, -1.06], [der_parcial_1, der_parcial_0])
# Out:
# [12-15 20:20:38][INFO] Se ajustarán 2 parámetros.
# array([-0.50323259,  1.49919762])

# %%
import numpy as np
import matplotlib.pyplot as plt

xs = np.array([3.38, 0.35, 2.07, -0.45, -0.55, -1.06, -2.77,
               3.08, -3.98, -5, -3.18, -1.96, 2.37, -1.66, 4.09])

ys = np.array([-0.04, 1.28, 0.65, 2.18, 1.70, 1.96, 3.36,
               0.18, 3.35, 4.16, 2.95, 2.34, 0.38, 1.75, -1.06])

m = -0.50323259
b = 1.49919762

x_recta = np.linspace(xs.min(), xs.max(), 200)
y_recta = m * x_recta + b

plt.figure(figsize=(8, 5))

plt.scatter(xs, ys, color='red', s=60, label="Puntos dados")
plt.plot(x_recta, y_recta, color='blue',
         label=f"Recta mínimos cuadrados\n$y = {m:.3f}x + {b:.3f}$")

plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# Conjunto de datos 2
#
# $(3.38, 15.65) (0.35, -11.20) (2.07, -4.00) (-0.45, 18.03) (-0.56, 7.94) (-1.06, 15.32) (-2.78, -4.40) (3.08, 1.39) (-3.99, -11.92) (-5.00, -90.24) (-3.18, 6.92) (-1.97, 28.35) (2.37, -2.41) (-1.67, -5.47) (4.09, 35.91) (-4.60, -55.53) (2.68, 0.77) (2.78, 4.79) (-3.79, -27.05) (-1.87, 2.85)$

# %%
import numpy as np
import logging

logging.basicConfig(
    format='[%(asctime)s][%(levelname)s] %(message)s',
    datefmt='%m-%d %H:%M:%S',
    level=logging.INFO
)

# Derivada parcial respecto a d
def der_parcial_0(xs: list, ys: list):
    c_ind = sum(ys)

    c_3 = sum(xi**3 for xi in xs)
    c_2 = sum(xi**2 for xi in xs)
    c_1 = sum(xs)
    c_0 = len(xs)

    return (c_3, c_2, c_1, c_0, c_ind)


# Derivada parcial respecto a c
def der_parcial_1(xs: list, ys: list):
    c_ind = sum(xi * yi for xi, yi in zip(xs, ys))

    c_3 = sum(xi**4 for xi in xs)
    c_2 = sum(xi**3 for xi in xs)
    c_1 = sum(xi**2 for xi in xs)
    c_0 = sum(xs)

    return (c_3, c_2, c_1, c_0, c_ind)


# Derivada parcial respecto a b
def der_parcial_2(xs: list, ys: list):
    c_ind = sum((xi**2) * yi for xi, yi in zip(xs, ys))

    c_3 = sum(xi**5 for xi in xs)
    c_2 = sum(xi**4 for xi in xs)
    c_1 = sum(xi**3 for xi in xs)
    c_0 = sum(xi**2 for xi in xs)

    return (c_3, c_2, c_1, c_0, c_ind)


# Derivada parcial respecto a a
def der_parcial_3(xs: list, ys: list):
    c_ind = sum((xi**3) * yi for xi, yi in zip(xs, ys))

    c_3 = sum(xi**6 for xi in xs)
    c_2 = sum(xi**5 for xi in xs)
    c_1 = sum(xi**4 for xi in xs)
    c_0 = sum(xi**3 for xi in xs)

    return (c_3, c_2, c_1, c_0, c_ind)

def ajustar_min_cuadrados(xs: list, ys: list, derivadas: list):
    n = len(derivadas)
    logging.info(f"Se ajustarán {n} parámetros.")

    A = []
    B = []

    for der in derivadas:
        *coeficientes, c_ind = der(xs, ys)
        A.append(coeficientes)
        B.append(c_ind)

    A = np.array(A, dtype=float)
    B = np.array(B, dtype=float)

    solucion = np.linalg.solve(A, B)
    print(solucion)

    return solucion

xs = [
    3.38, 0.35, 2.07, -0.45, -0.56, -1.06, -2.78, 3.08, -3.99, -5.00,
    -3.18, -1.97, 2.37, -1.67, 4.09, -4.60, 2.68, 2.78, -3.79, -1.87
]

ys = [
    15.65, -11.20, -4.00, 18.03, 7.94, 15.32, -4.40, 1.39, -11.92, -90.24,
    6.92, 28.35, -2.41, -5.47, 35.91, -55.53, 0.77, 4.79, -27.05, 2.85
]

ajustar_min_cuadrados(
    xs,
    ys,
    [der_parcial_3, der_parcial_2, der_parcial_1, der_parcial_0]
)
# Out:
# [12-15 20:22:24][INFO] Se ajustarán 4 parámetros.
# [ 1.04497792  0.03132741 -8.88066397  2.76228992]
# array([ 1.04497792,  0.03132741, -8.88066397,  2.76228992])

# %%
import numpy as np
import matplotlib.pyplot as plt

xs = np.array([
    3.38, 0.35, 2.07, -0.45, -0.56, -1.06, -2.78, 3.08, -3.99, -5.00,
    -3.18, -1.97, 2.37, -1.67, 4.09, -4.60, 2.68, 2.78, -3.79, -1.87
])

ys = np.array([
    15.65, -11.20, -4.00, 18.03, 7.94, 15.32, -4.40, 1.39, -11.92, -90.24,
    6.92, 28.35, -2.41, -5.47, 35.91, -55.53, 0.77, 4.79, -27.05, 2.85
])

a = 1.04497792
b = 0.03132741
c = -8.88066397
d = 2.76228992

x_curve = np.linspace(xs.min(), xs.max(), 400)
y_curve = a*x_curve**3 + b*x_curve**2 + c*x_curve + d

plt.figure(figsize=(8, 5))

plt.scatter(xs, ys, color='red', s=60, label="Conjunto de datos")
plt.plot(
    x_curve,
    y_curve,
    color='blue',
    label=(
        "Ajuste cúbico mínimos cuadrados\n"
        f"$y = {a:.3f}x^3 + {b:.3f}x^2 {c:+.3f}x {d:+.3f}$"
    )
)

plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste cúbico por mínimos cuadrados")
plt.legend()
plt.grid()

plt.show()
